# %% [markdown]
# # UTS Sistem Temu Kembali Informasi (STKI)
# # Nama: Dzaky Nitisara Ardell
# # NIM: A11.202X2.14299
# # Kelompok: A11.4703
#
# ## Tujuan
# Membangun sistem temu kembali informasi sederhana (mini search engine) dengan korpus teks kecil (5–15 dokumen) untuk memahami:
# - Document preprocessing
# - Boolean Retrieval Model
# - Vector Space Model (VSM)
# - Term weighting (TF-IDF)
# - Evaluasi (precision, recall, F1)
